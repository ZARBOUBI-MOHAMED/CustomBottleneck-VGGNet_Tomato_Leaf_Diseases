# %% [markdown]
# <a href="https://colab.research.google.com/github/ZARBOUBI-MOHAMED/CustomBottleneck-VGGNet_Tomato_Leaf_Diseases/blob/main/Models/GoogleNet/GoogleNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Connecte to driver**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # **Download the file.rar of the dataset to train the model**

# %%
#  input_fil  ===>  output_folder
# !unrar x "/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Dataset/Tomato_No_augmen.rar" "/content/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation                      OK
# Creating    /content/Tomato_No_augmen/Validation/Bacterial Spot       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Early Blight         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Healthy              OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Late Blight          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Leaf Mold            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Mosaic Virus         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Septoria Leaf Spot   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Spider Mite          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Target Spot          OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tomato_No_augmen/Validation/Yellow Leaf Curl Virus  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# # **############ GoogleNet ##################**

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dropout, Dense, Flatten, Input, concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.utils import plot_model
import pandas as pd
import time

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
custom_path = "GoogleNet/"
filename_1 = "GoogleNet.png"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

#************************************* input *************************************

# Parameters for images (size and scaling)
img_width, img_height = 224, 224

# Inception module function
def inception_module(x, filters_1x1, filters_3x3_reduce, filters_3x3, filters_5x5_reduce, filters_5x5, filters_pool_proj):
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu')(x)

    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu')(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu')(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu')(conv_5x5)

    pool_proj = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu')(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3)
    return output

# Input layer
input_layer = Input(shape=(img_width, img_height, 3))

# Stem of the network
x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu')(input_layer)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = Conv2D(192, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

# Inception modules
x = inception_module(x, 64, 96, 128, 16, 32, 32)
x = inception_module(x, 128, 128, 192, 32, 96, 64)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = inception_module(x, 192, 96, 208, 16, 48, 64)
x = inception_module(x, 160, 112, 224, 24, 64, 64)
x = inception_module(x, 128, 128, 256, 24, 64, 64)
x = inception_module(x, 112, 144, 288, 32, 64, 64)
x = inception_module(x, 256, 160, 320, 32, 128, 128)
x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
x = inception_module(x, 256, 160, 320, 32, 128, 128)
x = inception_module(x, 384, 192, 384, 48, 128, 128)

# Output layers
x = AveragePooling2D((7, 7), padding='same')(x)
x = Dropout(0.4)(x)
x = Flatten()(x)
output_layer = Dense(10, activation='softmax')(x)  # 10 output classes

# Create the model
model = Model(input_layer, output_layer)

#*******************************************************************************
# Display a summary of the custom model
model.summary()
#*******************************************************************************
# Visualize the model
plot_model(model, to_file=f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_1}", show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 112, 112, 64)         9472      ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 192)          110784    ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 28, 28, 192)          0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 96)           18528     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)           3088      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 192)          0         ['max_pooling2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)           12352     ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 128)          110720    ['conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 32)           12832     ['conv2d_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 32)           6176      ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 28, 256)          0         ['conv2d_2[0][0]',
#                                                                      'conv2d_4[0][0]',
#                                                                      'conv2d_6[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 28, 28, 32)           8224      ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 28, 28, 256)          0         ['concatenate[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 128)          32896     ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 192)          221376    ['conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 28, 28, 96)           76896     ['conv2d_11[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 28, 28, 64)           16448     ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate  (None, 28, 28, 480)          0         ['conv2d_8[0][0]',
#  )                                                                   'conv2d_10[0][0]',
#                                                                      'conv2d_12[0][0]',
#                                                                      'conv2d_13[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 480)          0         ['concatenate_1[0][0]']
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 96)           46176     ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 14, 14, 16)           7696      ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 480)          0         ['max_pooling2d_4[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 192)          92352     ['max_pooling2d_4[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 14, 14, 208)          179920    ['conv2d_15[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 48)           19248     ['conv2d_17[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 14, 14, 64)           30784     ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_14[0][0]',
#  )                                                                   'conv2d_16[0][0]',
#                                                                      'conv2d_18[0][0]',
#                                                                      'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_2[0][0]']
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 14, 14, 160)          82080     ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 14, 14, 224)          226016    ['conv2d_21[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_20[0][0]',
#  )                                                                   'conv2d_22[0][0]',
#                                                                      'conv2d_24[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 24)           12312     ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_3[0][0]']
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 14, 14, 128)          65664     ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 256)          295168    ['conv2d_27[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 14, 14, 64)           38464     ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate  (None, 14, 14, 512)          0         ['conv2d_26[0][0]',
#  )                                                                   'conv2d_28[0][0]',
#                                                                      'conv2d_30[0][0]',
#                                                                      'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 14, 14, 144)          73872     ['concatenate_4[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 32)           16416     ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 14, 14, 512)          0         ['concatenate_4[0][0]']
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 14, 14, 112)          57456     ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 14, 14, 288)          373536    ['conv2d_33[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 14, 14, 64)           51264     ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 14, 14, 64)           32832     ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate  (None, 14, 14, 528)          0         ['conv2d_32[0][0]',
#  )                                                                   'conv2d_34[0][0]',
#                                                                      'conv2d_36[0][0]',
#                                                                      'conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 14, 14, 160)          84640     ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 14, 14, 32)           16928     ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 528)          0         ['concatenate_5[0][0]']
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 14, 14, 256)          135424    ['concatenate_5[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 14, 14, 320)          461120    ['conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 14, 14, 128)          102528    ['conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 128)          67712     ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate  (None, 14, 14, 832)          0         ['conv2d_38[0][0]',
#  )                                                                   'conv2d_40[0][0]',
#                                                                      'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_6[0][0]']
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 7, 7, 160)            133280    ['max_pooling2d_10[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 7, 7, 32)             26656     ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooli  (None, 7, 7, 832)            0         ['max_pooling2d_10[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 7, 7, 256)            213248    ['max_pooling2d_10[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 7, 7, 320)            461120    ['conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 7, 7, 128)            102528    ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate  (None, 7, 7, 832)            0         ['conv2d_44[0][0]',
#  )                                                                   'conv2d_46[0][0]',
#                                                                      'conv2d_48[0][0]',
#                                                                      'conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 7, 7, 192)            159936    ['concatenate_7[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 7, 7, 48)             39984     ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooli  (None, 7, 7, 832)            0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_50 (Conv2D)          (None, 7, 7, 384)            319872    ['concatenate_7[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 7, 7, 384)            663936    ['conv2d_51[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 7, 7, 128)            153728    ['conv2d_53[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 7, 7, 128)            106624    ['max_pooling2d_12[0][0]']
#
#  concatenate_8 (Concatenate  (None, 7, 7, 1024)           0         ['conv2d_50[0][0]',
#  )                                                                   'conv2d_52[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]']
#
#  average_pooling2d (Average  (None, 1, 1, 1024)           0         ['concatenate_8[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 1, 1, 1024)           0         ['average_pooling2d[0][0]']
#
#  flatten (Flatten)           (None, 1024)                 0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 10)                   10250     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 5979642 (22.81 MB)
# Trainable params: 5979642 (22.81 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # **Experiment Configuration**

# %%
# Define the learning rate

learning_rate = 0.001

# Compile the model by specifying the learning rate

optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Compile the model

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define the paths of training and validation dataset
train_data_dir = '/content/Tomato_No_augmen/Train'
validation_data_dir = '/content/Tomato_No_augmen/Validation'

# %%
# Use ImageDataGenerator only for pixel scaling
batch_size = 32
datagen = ImageDataGenerator(rescale=1.0 / 255.0)

train_generator = datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 12707 images belonging to 10 classes.
# Found 3641 images belonging to 10 classes.

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
filename_2 = "Train/training_history.csv"
filename_3 = "Train/GoogleNet.h5"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Train the model
epochs = 100   # Number of training epochs *****************
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Start the timer
start_time = time.time()
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Train the model while collecting the training history
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    epochs=epochs)  # Add the CSVLogger callback

#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# Stop the timer
end_time = time.time()

# Calculate the training time
training_time = end_time - start_time
print(f"Training time: {training_time:.2f} seconds")
#%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

# Convert the history object to a DataFrame
history_df = pd.DataFrame(history.history)

# Save the history to a CSV file
history_df.to_csv('training_history.csv', index=False)

# Save the model after training if necessary
model.save('GoogleNet.h5')

# Save the history to a CSV file in Drive

history_df.to_csv(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_2}", index=False)

# Save the model in Drive
model.save(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_3}")
# Out:
# Epoch 1/100
# 397/397 [==============================] - 82s 139ms/step - loss: 1.8540 - accuracy: 0.3529 - val_loss: 1.4984 - val_accuracy: 0.4699
# Epoch 2/100
# 397/397 [==============================] - 54s 137ms/step - loss: 1.3393 - accuracy: 0.5236 - val_loss: 1.0825 - val_accuracy: 0.6139
# Epoch 3/100
# 397/397 [==============================] - 54s 137ms/step - loss: 1.0077 - accuracy: 0.6473 - val_loss: 0.7292 - val_accuracy: 0.7464
# Epoch 4/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.7591 - accuracy: 0.7381 - val_loss: 0.6540 - val_accuracy: 0.7707
# Epoch 5/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.5987 - accuracy: 0.7883 - val_loss: 0.5536 - val_accuracy: 0.8045
# Epoch 6/100
# 397/397 [==============================] - 55s 138ms/step - loss: 0.5156 - accuracy: 0.8170 - val_loss: 0.5983 - val_accuracy: 0.8012
# Epoch 7/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.4177 - accuracy: 0.8517 - val_loss: 0.3620 - val_accuracy: 0.8664
# Epoch 8/100
# 397/397 [==============================] - 55s 137ms/step - loss: 0.3737 - accuracy: 0.8677 - val_loss: 0.4478 - val_accuracy: 0.8319
# Epoch 9/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.3229 - accuracy: 0.8875 - val_loss: 0.4221 - val_accuracy: 0.8498
# Epoch 10/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.2792 - accuracy: 0.8998 - val_loss: 0.2961 - val_accuracy: 0.8955
# Epoch 11/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.2645 - accuracy: 0.9088 - val_loss: 0.4615 - val_accuracy: 0.8496
# Epoch 12/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.2344 - accuracy: 0.9157 - val_loss: 0.2790 - val_accuracy: 0.9065
# Epoch 13/100
# 397/397 [==============================] - 49s 124ms/step - loss: 0.2012 - accuracy: 0.9299 - val_loss: 0.2479 - val_accuracy: 0.9162
# Epoch 14/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.1859 - accuracy: 0.9364 - val_loss: 0.2714 - val_accuracy: 0.9057
# Epoch 15/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.1952 - accuracy: 0.9344 - val_loss: 0.7303 - val_accuracy: 0.8089
# Epoch 16/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.2103 - accuracy: 0.9293 - val_loss: 0.2612 - val_accuracy: 0.9143
# Epoch 17/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.1466 - accuracy: 0.9489 - val_loss: 0.2332 - val_accuracy: 0.9195
# Epoch 18/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.1523 - accuracy: 0.9482 - val_loss: 0.2796 - val_accuracy: 0.9093
# Epoch 19/100
# 397/397 [==============================] - 50s 127ms/step - loss: 0.1383 - accuracy: 0.9547 - val_loss: 0.3861 - val_accuracy: 0.8930
# Epoch 20/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.1369 - accuracy: 0.9520 - val_loss: 0.2436 - val_accuracy: 0.9209
# Epoch 21/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.1207 - accuracy: 0.9583 - val_loss: 0.2299 - val_accuracy: 0.9267
# Epoch 22/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.1330 - accuracy: 0.9553 - val_loss: 0.1773 - val_accuracy: 0.9455
# Epoch 23/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0827 - accuracy: 0.9733 - val_loss: 0.2176 - val_accuracy: 0.9375
# Epoch 24/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0935 - accuracy: 0.9688 - val_loss: 0.1841 - val_accuracy: 0.9455
# Epoch 25/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0923 - accuracy: 0.9696 - val_loss: 0.1591 - val_accuracy: 0.9469
# Epoch 26/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.2118 - accuracy: 0.9340 - val_loss: 0.1993 - val_accuracy: 0.9361
# Epoch 27/100
# 397/397 [==============================] - 50s 127ms/step - loss: 0.1350 - accuracy: 0.9555 - val_loss: 0.2036 - val_accuracy: 0.9320
# Epoch 28/100
# 397/397 [==============================] - 52s 132ms/step - loss: 0.1054 - accuracy: 0.9658 - val_loss: 0.2199 - val_accuracy: 0.9400
# Epoch 29/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.1128 - accuracy: 0.9631 - val_loss: 0.2139 - val_accuracy: 0.9317
# Epoch 30/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0828 - accuracy: 0.9735 - val_loss: 0.1650 - val_accuracy: 0.9508
# Epoch 31/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.1103 - accuracy: 0.9647 - val_loss: 0.1802 - val_accuracy: 0.9439
# Epoch 32/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0790 - accuracy: 0.9736 - val_loss: 0.1641 - val_accuracy: 0.9499
# Epoch 33/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0741 - accuracy: 0.9750 - val_loss: 0.2574 - val_accuracy: 0.9264
# Epoch 34/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0869 - accuracy: 0.9720 - val_loss: 0.1694 - val_accuracy: 0.9593
# Epoch 35/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0783 - accuracy: 0.9748 - val_loss: 0.2880 - val_accuracy: 0.9253
# Epoch 36/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0611 - accuracy: 0.9800 - val_loss: 0.1768 - val_accuracy: 0.9524
# Epoch 37/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0743 - accuracy: 0.9756 - val_loss: 0.2392 - val_accuracy: 0.9320
# Epoch 38/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0876 - accuracy: 0.9715 - val_loss: 0.5935 - val_accuracy: 0.8175
# Epoch 39/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0954 - accuracy: 0.9680 - val_loss: 0.1697 - val_accuracy: 0.9477
# Epoch 40/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0651 - accuracy: 0.9796 - val_loss: 0.2861 - val_accuracy: 0.9217
# Epoch 41/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0845 - accuracy: 0.9720 - val_loss: 0.1802 - val_accuracy: 0.9488
# Epoch 42/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0563 - accuracy: 0.9794 - val_loss: 0.1624 - val_accuracy: 0.9527
# Epoch 43/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0423 - accuracy: 0.9862 - val_loss: 0.2509 - val_accuracy: 0.9372
# Epoch 44/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.0675 - accuracy: 0.9785 - val_loss: 0.1965 - val_accuracy: 0.9428
# Epoch 45/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0549 - accuracy: 0.9827 - val_loss: 0.2141 - val_accuracy: 0.9397
# Epoch 46/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0788 - accuracy: 0.9764 - val_loss: 0.1803 - val_accuracy: 0.9461
# Epoch 47/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0563 - accuracy: 0.9816 - val_loss: 0.1668 - val_accuracy: 0.9555
# Epoch 48/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0563 - accuracy: 0.9826 - val_loss: 0.2363 - val_accuracy: 0.9300
# Epoch 49/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0625 - accuracy: 0.9804 - val_loss: 0.2184 - val_accuracy: 0.9369
# Epoch 50/100
# 397/397 [==============================] - 50s 127ms/step - loss: 0.0613 - accuracy: 0.9797 - val_loss: 0.1578 - val_accuracy: 0.9569
# Epoch 51/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0683 - accuracy: 0.9800 - val_loss: 0.1994 - val_accuracy: 0.9386
# Epoch 52/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0604 - accuracy: 0.9806 - val_loss: 0.1834 - val_accuracy: 0.9519
# Epoch 53/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0650 - accuracy: 0.9797 - val_loss: 0.2064 - val_accuracy: 0.9381
# Epoch 54/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0490 - accuracy: 0.9845 - val_loss: 0.2285 - val_accuracy: 0.9392
# Epoch 55/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0765 - accuracy: 0.9764 - val_loss: 0.2014 - val_accuracy: 0.9455
# Epoch 56/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0397 - accuracy: 0.9873 - val_loss: 0.2083 - val_accuracy: 0.9419
# Epoch 57/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0782 - accuracy: 0.9757 - val_loss: 0.2043 - val_accuracy: 0.9430
# Epoch 58/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0342 - accuracy: 0.9885 - val_loss: 0.1760 - val_accuracy: 0.9541
# Epoch 59/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.0401 - accuracy: 0.9890 - val_loss: 0.3266 - val_accuracy: 0.9165
# Epoch 60/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0708 - accuracy: 0.9779 - val_loss: 0.1890 - val_accuracy: 0.9458
# Epoch 61/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0463 - accuracy: 0.9853 - val_loss: 0.1625 - val_accuracy: 0.9549
# Epoch 62/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0291 - accuracy: 0.9916 - val_loss: 0.3805 - val_accuracy: 0.9065
# Epoch 63/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0754 - accuracy: 0.9749 - val_loss: 0.1949 - val_accuracy: 0.9466
# Epoch 64/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0514 - accuracy: 0.9830 - val_loss: 0.1968 - val_accuracy: 0.9516
# Epoch 65/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.0766 - accuracy: 0.9780 - val_loss: 0.1805 - val_accuracy: 0.9541
# Epoch 66/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.1429 - val_accuracy: 0.9632
# Epoch 67/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0334 - accuracy: 0.9901 - val_loss: 0.1862 - val_accuracy: 0.9585
# Epoch 68/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 0.2192 - val_accuracy: 0.9508
# Epoch 69/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0945 - accuracy: 0.9718 - val_loss: 0.2094 - val_accuracy: 0.9447
# Epoch 70/100
# 397/397 [==============================] - 53s 135ms/step - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.2040 - val_accuracy: 0.9519
# Epoch 71/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0293 - accuracy: 0.9899 - val_loss: 0.1745 - val_accuracy: 0.9607
# Epoch 72/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0590 - accuracy: 0.9825 - val_loss: 0.1710 - val_accuracy: 0.9508
# Epoch 73/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0452 - accuracy: 0.9849 - val_loss: 0.3335 - val_accuracy: 0.9181
# Epoch 74/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0524 - accuracy: 0.9845 - val_loss: 0.1837 - val_accuracy: 0.9577
# Epoch 75/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0541 - accuracy: 0.9841 - val_loss: 0.2616 - val_accuracy: 0.9347
# Epoch 76/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0524 - accuracy: 0.9848 - val_loss: 0.2650 - val_accuracy: 0.9212
# Epoch 77/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0456 - accuracy: 0.9862 - val_loss: 0.1769 - val_accuracy: 0.9558
# Epoch 78/100
# 397/397 [==============================] - 49s 125ms/step - loss: 0.0323 - accuracy: 0.9905 - val_loss: 0.2078 - val_accuracy: 0.9497
# Epoch 79/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0435 - accuracy: 0.9862 - val_loss: 0.2279 - val_accuracy: 0.9472
# Epoch 80/100
# 397/397 [==============================] - 50s 125ms/step - loss: 0.0439 - accuracy: 0.9860 - val_loss: 0.2349 - val_accuracy: 0.9436
# Epoch 81/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0543 - accuracy: 0.9826 - val_loss: 0.1315 - val_accuracy: 0.9610
# Epoch 82/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0603 - accuracy: 0.9805 - val_loss: 0.1708 - val_accuracy: 0.9502
# Epoch 83/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0479 - accuracy: 0.9856 - val_loss: 0.2262 - val_accuracy: 0.9381
# Epoch 84/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0296 - accuracy: 0.9901 - val_loss: 0.1812 - val_accuracy: 0.9602
# Epoch 85/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0485 - accuracy: 0.9850 - val_loss: 0.1909 - val_accuracy: 0.9486
# Epoch 86/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0559 - accuracy: 0.9834 - val_loss: 0.2753 - val_accuracy: 0.9450
# Epoch 87/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0349 - accuracy: 0.9888 - val_loss: 0.2247 - val_accuracy: 0.9499
# Epoch 88/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0339 - accuracy: 0.9884 - val_loss: 0.2447 - val_accuracy: 0.9394
# Epoch 89/100
# 397/397 [==============================] - 54s 135ms/step - loss: 0.0487 - accuracy: 0.9834 - val_loss: 0.2346 - val_accuracy: 0.9508
# Epoch 90/100
# 397/397 [==============================] - 55s 137ms/step - loss: 0.0580 - accuracy: 0.9822 - val_loss: 0.1644 - val_accuracy: 0.9571
# Epoch 91/100
# 397/397 [==============================] - 52s 130ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.1599 - val_accuracy: 0.9605
# Epoch 92/100
# 397/397 [==============================] - 50s 127ms/step - loss: 0.0504 - accuracy: 0.9848 - val_loss: 0.1970 - val_accuracy: 0.9469
# Epoch 93/100
# 397/397 [==============================] - 54s 137ms/step - loss: 0.0428 - accuracy: 0.9878 - val_loss: 0.2574 - val_accuracy: 0.9353
# Epoch 94/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0435 - accuracy: 0.9860 - val_loss: 0.2313 - val_accuracy: 0.9416
# Epoch 95/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.1580 - val_accuracy: 0.9621
# Epoch 96/100
# 397/397 [==============================] - 54s 136ms/step - loss: 0.0623 - accuracy: 0.9808 - val_loss: 0.3275 - val_accuracy: 0.9187
# Epoch 97/100
# 397/397 [==============================] - 51s 129ms/step - loss: 0.0461 - accuracy: 0.9860 - val_loss: 0.1779 - val_accuracy: 0.9544
# Epoch 98/100
# 397/397 [==============================] - 50s 126ms/step - loss: 0.0355 - accuracy: 0.9886 - val_loss: 0.1489 - val_accuracy: 0.9665
# Epoch 99/100
# 397/397 [==============================] - 51s 128ms/step - loss: 0.0575 - accuracy: 0.9832 - val_loss: 0.3344 - val_accuracy: 0.9259
# Epoch 100/100
# 397/397 [==============================] - 51s 127ms/step - loss: 0.0412 - accuracy: 0.9862 - val_loss: 0.2791 - val_accuracy: 0.9353
# Training time: 6376.93 seconds
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd

# Convert the history object to a DataFrame
history_df = pd.DataFrame(history.history)

# Save the history to a CSV file
history_df.to_csv('training_history.csv', index=False)

# Save the model after training if necessary
model.save('GoogleNet.h5')

# Save the history to a CSV file in Drive

history_df.to_csv(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_2}", index=False)

# Save the model in Drive
model.save(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_3}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # **Display and save each graph separately in EPS format**

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
filename_4 = "Train/train_val_loss.eps"
filename_5 = "Train/train_val_accuracy.eps"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Display and save the loss graph
plt.figure(figsize=(6, 4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.tight_layout()
plt.savefig(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_4}", format='eps', bbox_inches='tight')
plt.show()

# Display and save the accuracy graph
plt.figure(figsize=(6, 4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train and Validation Accuracy')
plt.tight_layout()
plt.savefig(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_5}", format='eps', bbox_inches='tight')
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # **Plot the training curves of loss and accuracy from the CSV file**

# %%
import pandas as pd
import matplotlib.pyplot as plt

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
custom_path = "GoogleNet/"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
filename_6 = "Train/training_history.csv"
filename_7 = "Train/Train_val_loss_2.eps"
filename_8 = "Train/train_val_accuracy_2.eps"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Load training data from the CSV file
log_data = pd.read_csv(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_6}")

# Plot the loss graph
plt.figure(figsize=(6, 4))
plt.plot(log_data['loss'], label='Train Loss')
plt.plot(log_data['val_loss'], label='Validation Loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.tight_layout()
plt.savefig(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_7}", format='eps', bbox_inches='tight')
plt.show()

# Plot the accuracy graph
plt.figure(figsize=(6, 4))
plt.plot(log_data['accuracy'], label='Train Accuracy')
plt.plot(log_data['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train and Validation Accuracy')
plt.tight_layout()
plt.savefig(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_8}", format='eps', bbox_inches='tight')
plt.show()
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # **Test Model**

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
custom_path = "GoogleNet/"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
filename_9 = "Train/GoogleNet.h5"
filename_10 = "Train/confusion_matrix.eps"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# Test directory

test_data_dir = '/content/Tomato_No_augmen/Test'

# Load the pre-trained model from the file
model = load_model(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_9}")

# Parameters for the images (size and scaling)
img_width, img_height = 224, 224
batch_size = 32

# Create a data generator for scaling the test images
datagen = ImageDataGenerator(rescale=1.0 / 255.0)

# Use the model to make predictions on the test data
test_generator = datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False)  # Ensure the data remains in the correct order

# Model predictions on the test data
predictions = model.predict(test_generator, steps=(test_generator.samples + batch_size - 1) // batch_size)

# Get the true labels from the test data
true_labels = test_generator.classes

# Get the predicted classes
predicted_labels = np.argmax(predictions, axis=1)

# Compute the confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix
class_names = list(test_generator.class_indices.keys())

# Create a figure with a specific size in inches
plt.figure(figsize=(10, 8))

sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')



# Compute the metrics
accuracy = accuracy_score(true_labels, predicted_labels)
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Display the metrics
print(f'Accuracy: {accuracy * 100:.2f}%')
print(f'Precision: {precision * 100:.2f}%')
print(f'Recall: {recall * 100:.2f}%')
print(f'F1 Score: {f1 * 100:.2f}%')

# Save the confusion matrix in EPS format
plt.savefig(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_10}", format='eps', bbox_inches='tight')
plt.show()
# Out:
# Found 1812 images belonging to 10 classes.
# 57/57 [==============================] - 6s 99ms/step
# Accuracy: 93.98%
# Precision: 94.37%
# Recall: 93.98%
# F1 Score: 93.91%

# %% [markdown]
# # **Calculate the number of FLOPs (Floating Point Operations per Second)**

# %%
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
custom_path = "GoogleNet/"
filename_9 = "Train/GoogleNet.h5"
#@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@

# %%
# Import required libraries
import tensorflow as tf
from tensorflow.keras.models import load_model

# Load the model
model = load_model(f"/content/gdrive/MyDrive/Colab Notebooks/Tomato_Leaf_Diseases/Models/{custom_path}{filename_9}")

# Create a concrete function
@tf.function
def model_fn(inputs):
    return model(inputs)

# Convert the model to a concrete function
input_shape = model.input_shape[1:]  # Exclude batch size
inputs = tf.TensorSpec([1, *input_shape], tf.float32)  # Batch size of 1
concrete_function = model_fn.get_concrete_function(inputs)

# Get the frozen graph
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
frozen_func = convert_variables_to_constants_v2(concrete_function)
graph_def = frozen_func.graph.as_graph_def()

# Calculate FLOPs using tf.compat.v1
tf.compat.v1.reset_default_graph()
with tf.compat.v1.Session() as sess:
    tf.compat.v1.import_graph_def(graph_def, name="")
    flops = tf.compat.v1.profiler.profile(
        sess.graph,
        options=tf.compat.v1.profiler.ProfileOptionBuilder.float_operation(),
    )

    # Display FLOPs in billions
    flops_in_billions = flops.total_float_ops / 1e9
    print(f"FLOPs: {flops_in_billions:.2f} Billion")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# FLOPs: 3.15 Billion
